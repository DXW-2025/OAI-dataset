# %%
import pandas as pd
import numpy as np
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

class FilePreprocessor:
    def __init__(self, file_path):
        """
        初始化文件预处理器
        
        Args:
            file_path (str): 文件路径
        """
        self.file_path = Path(file_path)
        self.df = None
        self.column_types = {}  # 存储列类型信息
        self.processed_df = None
        
    def load_file(self):
        """加载文件"""
        if self.file_path.suffix == '.csv':
            self.df = pd.read_csv(self.file_path)
        elif self.file_path.suffix in ['.xlsx', '.xls']:
            self.df = pd.read_excel(self.file_path)
        else:
            raise ValueError("不支持的文件格式。请使用CSV或Excel文件")
        
        print(f"加载文件成功，原始数据形状: {self.df.shape}")
        return self.df
    
    def remove_empty_columns(self):
        """删除空的列并向左合并其他列"""
        if self.df is None:
            self.load_file()
            
        # 记录原始列名
        original_columns = self.df.columns.tolist()
        
        # 找出所有完全为空的列
        empty_cols = self.df.columns[self.df.isna().all()].tolist()
        
        if empty_cols:
            print(f"发现 {len(empty_cols)} 个空列: {empty_cols}")
            # 删除空列
            self.df = self.df.drop(columns=empty_cols)
            print("空列已删除")
        else:
            print("未发现空列")
        
        print(f"删除空列后数据形状: {self.df.shape}")
        return self.df
    
    def detect_column_type(self, column):
        """
        检测列的类型
        
        Args:
            column (pd.Series): 数据列
            
        Returns:
            str: 列类型 - 'binary', 'ordinal', 'continuous'
        """
        # 获取非空值
        non_null_vals = column.dropna()
        
        if len(non_null_vals) == 0:
            # 如果全是空值，根据列名猜测类型
            col_name = column.name.lower()
            if 'id' in col_name or '编号' in col_name:
                return 'id'
            else:
                return 'continuous'  # 默认作为连续变量处理
        
        # 计算唯一值数量（非空）
        unique_vals = non_null_vals.nunique()
        
        # 如果是ID列（第一列），特殊处理
        if column.name == self.df.columns[0] or 'id' in str(column.name).lower():
            return 'id'
        
        # 判断是否为二分类变量
        if unique_vals <= 2:
            # 检查值是否为数值型或可转换为数值型
            try:
                # 尝试转换为数值型
                numeric_vals = pd.to_numeric(non_null_vals, errors='coerce')
                if numeric_vals.notna().all():
                    return 'binary'
            except:
                # 如果转换失败，检查是否是字符串类型的二分类
                if unique_vals <= 2:
                    return 'binary'
        
        # 判断是否为定序变量
        # 定序变量通常是有序的分类变量，如等级、评分等
        try:
            # 尝试转换为数值型
            numeric_vals = pd.to_numeric(non_null_vals, errors='coerce')
            if numeric_vals.notna().all():
                # 如果值是整数且唯一值数量较少（通常 <= 10），可能是定序变量
                if (numeric_vals.apply(float.is_integer).all() and 
                    unique_vals <= 10 and 
                    unique_vals > 2):
                    return 'ordinal'
        except:
            pass
        
        # 默认作为连续变量
        return 'continuous'
    
    def process_binary_column(self, column):
        """处理二分类变量"""
        col_name = column.name
        
        # 首先转换为数值型
        try:
            numeric_col = pd.to_numeric(column, errors='coerce')
        except:
            # 如果是字符串，编码为数字
            unique_vals = column.dropna().unique()
            mapping = {val: i+1 for i, val in enumerate(unique_vals)}
            numeric_col = column.map(mapping)
        
        # 缺失值填充为0
        processed_col = numeric_col.fillna(0)
        
        # 确保只有0和1（如果原始有1,2，则映射为0,1）
        unique_nonzero = processed_col[processed_col != 0].unique()
        if len(unique_nonzero) == 1:
            # 如果只有一个非零值，将其映射为1
            nonzero_val = unique_nonzero[0]
            processed_col = processed_col.replace({nonzero_val: 1})
        elif len(unique_nonzero) == 2:
            # 如果有两个非零值，映射为0,1
            vals = sorted(unique_nonzero)
            processed_col = processed_col.replace({vals[0]: 0, vals[1]: 1})
        
        return processed_col
    
    def process_ordinal_column(self, column):
        """处理定序变量"""
        # 计算众数
        mode_val = column.mode()
        if not mode_val.empty:
            fill_value = mode_val.iloc[0]
        else:
            fill_value = column.median()  # 如果没有众数，使用中位数
        
        # 填充缺失值
        processed_col = column.fillna(fill_value)
        
        # 确保是数值型
        try:
            processed_col = pd.to_numeric(processed_col, errors='coerce')
        except:
            pass
            
        return processed_col
    
    def process_continuous_column(self, column):
        """处理连续变量"""
        # 计算平均值
        mean_val = column.mean()
        
        # 填充缺失值
        processed_col = column.fillna(mean_val)
        
        return processed_col
    
    def preprocess_file(self, save_output=True, output_path=None):
        """
        主处理函数
        
        Args:
            save_output (bool): 是否保存输出文件
            output_path (str): 输出文件路径
            
        Returns:
            pd.DataFrame: 处理后的数据框
        """
        print("开始文件预处理...")
        
        # 1. 加载文件
        self.load_file()
        
        # 2. 删除空列
        self.remove_empty_columns()
        
        # 3. 创建处理后的数据框副本
        self.processed_df = self.df.copy()
        
        print("\n检测列类型并处理缺失值...")
        print("-" * 50)
        
        # 4. 遍历每一列（除第一列ID列外）
        for i, col_name in enumerate(self.processed_df.columns):
            column = self.processed_df[col_name]
            
            # 检测列类型
            col_type = self.detect_column_type(column)
            self.column_types[col_name] = col_type
            
            # 根据类型处理
            if col_type == 'id':
                # ID列不处理
                print(f"列 {i+1}: {col_name} - ID列 (跳过处理)")
                continue
            elif col_type == 'binary':
                print(f"列 {i+1}: {col_name} - 二分类变量")
                self.processed_df[col_name] = self.process_binary_column(column)
            elif col_type == 'ordinal':
                print(f"列 {i+1}: {col_name} - 定序变量")
                self.processed_df[col_name] = self.process_ordinal_column(column)
            elif col_type == 'continuous':
                print(f"列 {i+1}: {col_name} - 连续变量")
                self.processed_df[col_name] = self.process_continuous_column(column)
        
        print("-" * 50)
        print(f"处理完成！最终数据形状: {self.processed_df.shape}")
        
        # 5. 保存输出文件
        if save_output:
            if output_path is None:
                # 生成默认输出文件名
                suffix = self.file_path.suffix
                output_path = str(self.file_path).replace(suffix, f"_processed{suffix}")
            
            if self.file_path.suffix == '.csv':
                self.processed_df.to_csv(output_path, index=False)
            else:
                self.processed_df.to_excel(output_path, index=False)
            
            print(f"处理后的文件已保存至: {output_path}")
        
        return self.processed_df
    
    def get_summary(self):
        """获取处理摘要"""
        if self.processed_df is None:
            return "请先运行 preprocess_file() 方法"
        
        summary = {
            '原始文件': str(self.file_path),
            '原始数据形状': f"{self.df.shape[0]} 行 × {self.df.shape[1]} 列",
            '处理后形状': f"{self.processed_df.shape[0]} 行 × {self.processed_df.shape[1]} 列",
            '列类型统计': {
                'ID列': sum(1 for t in self.column_types.values() if t == 'id'),
                '二分类变量': sum(1 for t in self.column_types.values() if t == 'binary'),
                '定序变量': sum(1 for t in self.column_types.values() if t == 'ordinal'),
                '连续变量': sum(1 for t in self.column_types.values() if t == 'continuous'),
            },
            '列详细信息': self.column_types
        }
        
        return summary


def main():
    """主函数示例"""
    import argparse
    
    parser = argparse.ArgumentParser(description='文件预处理程序')
    parser.add_argument('file_path', help='输入文件路径')
    parser.add_argument('--output', '-o', help='输出文件路径（可选）')
    parser.add_argument('--no-save', action='store_true', help='不保存输出文件')
    
    args = parser.parse_args()
    
    try:
        # 创建预处理器实例
        preprocessor = FilePreprocessor(args.file_path)
        
        # 执行预处理
        processed_df = preprocessor.preprocess_file(
            save_output=not args.no_save,
            output_path=args.output
        )
        
        # 显示摘要
        print("\n" + "="*50)
        print("处理摘要")
        print("="*50)
        summary = preprocessor.get_summary()
        
        if isinstance(summary, dict):
            for key, value in summary.items():
                if key == '列详细信息':
                    print(f"\n{key}:")
                    for col, col_type in value.items():
                        print(f"  {col}: {col_type}")
                elif key == '列类型统计':
                    print(f"\n{key}:")
                    for type_name, count in value.items():
                        print(f"  {type_name}: {count}")
                else:
                    print(f"{key}: {value}")
        
        print("\n前5行数据预览:")
        print(processed_df.head())
        
    except Exception as e:
        print(f"处理过程中发生错误: {e}")
        import traceback
        traceback.print_exc()


if __name__ == "__main__":
    # 直接运行示例
    print("文件预处理程序")
    print("="*50)
    
    # 示例用法1: 直接指定文件
    # preprocessor = FilePreprocessor("your_file.csv")
    # processed_df = preprocessor.preprocess_file()
    
    # 示例用法2: 使用交互式输入
    file_path =r"C:\Users\DXW\Desktop\半月板手术_predictor.xlsx"
    
    if file_path:
        preprocessor = FilePreprocessor(file_path)
        processed_df = preprocessor.preprocess_file()
        
        # 显示摘要
        print("\n" + "="*50)
        print("处理摘要")
        print("="*50)
        summary = preprocessor.get_summary()
        
        if isinstance(summary, dict):
            for key, value in summary.items():
                if key == '列详细信息':
                    print(f"\n{key}:")
                    for col, col_type in value.items():
                        print(f"  {col}: {col_type}")
                elif key == '列类型统计':
                    print(f"\n{key}:")
                    for type_name, count in value.items():
                        print(f"  {type_name}: {count}")
                else:
                    print(f"{key}: {value}")
        
        print("\n前5行数据预览:")
        print(processed_df.head())
    else:
        print("使用命令行运行: python script.py your_file.csv")
# Out:
# 文件预处理程序
# ==================================================
# 开始文件预处理...
# 加载文件成功，原始数据形状: (300, 356)
# 发现 59 个空列: ['Unnamed: 0', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'HPNRDK', 'HPNLDK', 'BPDK', 'Unnamed: 176', 'Unnamed: 198', 'Unnamed: 200', 'Unnamed: 202', 'Unnamed: 203', 'Unnamed: 204', 'Unnamed: 217', 'Unnamed: 218', 'Unnamed: 219', 'Unnamed: 220', 'Unnamed: 221', 'Unnamed: 222', 'Unnamed: 223', 'Unnamed: 224', 'Unnamed: 226', 'Unnamed: 228', 'Unnamed: 229', 'Unnamed: 240', 'Unnamed: 241', 'Unnamed: 245', 'Unnamed: 249', 'Unnamed: 255', 'Unnamed: 262', 'Unnamed: 265', 'Unnamed: 274', 'Unnamed: 278', 'Unnamed: 279', 'Unnamed: 280', 'Unnamed: 281', 'Unnamed: 282', 'Unnamed: 283', 'Unnamed: 284', 'Unnamed: 285', 'Unnamed: 286', 'Unnamed: 287', 'Unnamed: 288', 'Unnamed: 289', 'Unnamed: 290', 'Unnamed: 291', 'Unnamed: 292', 'Unnamed: 293', 'Unnamed: 301', 'Unnamed: 302', 'Unnamed: 310', 'Unnamed: 311', 'Unnamed: 328', 'Unnamed: 330', 'Unnamed: 332', 'Unnamed: 334']
# 空列已删除
# 删除空列后数据形状: (300, 297)
#
# 检测列类型并处理缺失值...
# --------------------------------------------------
# 列 1: ID - ID列 (跳过处理)
# 列 2: side - ID列 (跳过处理)
# 列 3: SF1 - 定序变量
# 列 4: SF2 - 定序变量
# 列 5: SF3 - 定序变量
# 列 6: SF4 - 定序变量
# 列 7: SF5 - 定序变量
# 列 8: SF6 - 定序变量
# 列 9: SF7 - 定序变量
# 列 10: SF8 - 定序变量
# 列 11: SF9 - 定序变量
# 列 12: SF10 - 定序变量
# 列 13: SF11 - 定序变量
# 列 14: SF12 - 定序变量
# 列 15: KPNR12 - 二分类变量
# 列 16: KPNR12M - 连续变量
# 列 17: KPNL12 - 二分类变量
# 列 18: KPNL12M - 连续变量
# 列 19: KPACT30 - 二分类变量
# 列 20: WPRKN1 - 连续变量
# 列 21: WPRKN2 - 定序变量
# 列 22: WPRKN3 - 定序变量
# 列 23: WPRKN4 - 定序变量
# 列 24: WPRKN5 - 定序变量
# 列 25: KPRKN1 - 定序变量
# 列 26: KPRKN2 - 连续变量
# 列 27: KPRKN3 - 定序变量
# 列 28: P7RKFR - 定序变量
# 列 29: WSRKN1 - 连续变量
# 列 30: WSRKN2 - 连续变量
# 列 31: KSXRKN1 - 定序变量
# 列 32: KSXRKN2 - 连续变量
# 列 33: KSXRKN3 - 连续变量
# 列 34: KSXRKN4 - 连续变量
# 列 35: KSXRKN5 - 连续变量
# 列 36: DIRKN1 - 定序变量
# 列 37: DIRKN2 - 定序变量
# 列 38: DIRKN3 - 连续变量
# 列 39: DIRKN4 - 连续变量
# 列 40: DIRKN5 - 定序变量
# 列 41: DIRKN6 - 连续变量
# 列 42: DIRKN7 - 定序变量
# 列 43: DIRKN8 - 定序变量
# 列 44: DIRKN9 - 连续变量
# 列 45: DIRKN10 - 连续变量
# 列 46: DIRKN11 - 连续变量
# 列 47: DIRKN12 - 连续变量
# 列 48: DIRKN13 - 定序变量
# 列 49: DIRKN14 - 连续变量
# 列 50: DIRKN15 - 定序变量
# 列 51: DIRKN16 - 定序变量
# 列 52: DIRKN17 - 连续变量
# 列 53: WPLKN1 - 连续变量
# 列 54: WPLKN2 - 定序变量
# 列 55: WPLKN3 - 连续变量
# 列 56: WPLKN4 - 连续变量
# 列 57: WPLKN5 - 连续变量
# 列 58: KPLKN1 - 定序变量
# 列 59: KPLKN2 - 定序变量
# 列 60: KPLKN3 - 定序变量
# 列 61: P7LKFR - 定序变量
# 列 62: WSLKN1 - 定序变量
# 列 63: WSLKN2 - 连续变量
# 列 64: KSXLKN1 - 定序变量
# 列 65: KSXLKN2 - 定序变量
# 列 66: KSXLKN3 - 定序变量
# 列 67: KSXLKN4 - 定序变量
# 列 68: KSXLKN5 - 定序变量
# 列 69: DILKN1 - 定序变量
# 列 70: DILKN2 - 定序变量
# 列 71: DILKN3 - 定序变量
# 列 72: DILKN4 - 连续变量
# 列 73: DILKN5 - 定序变量
# 列 74: DILKN6 - 连续变量
# 列 75: DILKN7 - 定序变量
# 列 76: DILKN8 - 定序变量
# 列 77: DILKN9 - 连续变量
# 列 78: DILKN10 - 连续变量
# 列 79: DILKN11 - 连续变量
# 列 80: DILKN12 - 连续变量
# 列 81: DILKN13 - 定序变量
# 列 82: DILKN14 - 连续变量
# 列 83: DILKN15 - 定序变量
# 列 84: DILKN16 - 定序变量
# 列 85: DILKN17 - 连续变量
# 列 86: KOOSFX1 - 定序变量
# 列 87: KOOSFX2 - 定序变量
# 列 88: KOOSFX3 - 定序变量
# 列 89: KOOSFX4 - 定序变量
# 列 90: KOOSFX5 - 定序变量
# 列 91: KQOL1 - 连续变量
# 列 92: KQOL2 - 连续变量
# 列 93: KQOL3 - 连续变量
# 列 94: KQOL4 - 连续变量
# 列 95: KGLRS - 连续变量
# 列 96: HPNR12 - 二分类变量
# 列 97: HPNRIL - 二分类变量
# 列 98: HPNROL - 二分类变量
# 列 99: HPNRFL - 二分类变量
# 列 100: HPNRB - 二分类变量
# 列 101: HPNRLB - 二分类变量
# 列 102: HPNL12 - 二分类变量
# 列 103: HPNLIL - 二分类变量
# 列 104: HPNLOL - 二分类变量
# 列 105: HPNLFL - 二分类变量
# 列 106: HPNLB - 二分类变量
# 列 107: HPNLLB - 二分类变量
# 列 108: BP30 - 二分类变量
# 列 109: BP30OFT - 定序变量
# 列 110: BPBAD - 定序变量
# 列 111: BPUB - 二分类变量
# 列 112: BPMB - 二分类变量
# 列 113: BPLB - 二分类变量
# 列 114: BPB - 二分类变量
# 列 115: OJPNRS - 二分类变量
# 列 116: OJPNLS - 二分类变量
# 列 117: OJPNRE - 二分类变量
# 列 118: OJPNLE - 二分类变量
# 列 119: OJPNRW - 二分类变量
# 列 120: OJPNLW - 二分类变量
# 列 121: OJPNRH - 二分类变量
# 列 122: OJPNLH - 二分类变量
# 列 123: OJPNRA - 二分类变量
# 列 124: OJPNLA - 二分类变量
# 列 125: OJPNRF - 二分类变量
# 列 126: OJPNLF - 二分类变量
# 列 127: OJPNNK - 二分类变量
# 列 128: OJPNNO - 二分类变量
# 列 129: WOMTSL - 连续变量
# 列 130: LKSX - 连续变量
# 列 131: KPA30CV - 二分类变量
# 列 132: KPL12CV - 二分类变量
# 列 133: BPBEDCV - 定序变量
# 列 134: BPTOT - 连续变量
# 列 135: RKP30CV - 二分类变量
# 列 136: KPACDCV - 连续变量
# 列 137: WOMSTFL - 连续变量
# 列 138: PMLKRCV - 连续变量
# 列 139: KOOSYML - 连续变量
# 列 140: HPR12CV - 二分类变量
# 列 141: KOOSKPL - 连续变量
# 列 142: KOOSFSR - 连续变量
# 列 143: P7LKRCV - 连续变量
# 列 144: BPDAYCV - 连续变量
# 列 145: RKSX - 连续变量
# 列 146: WOMSTFR - 连续变量
# 列 147: KOOSYMR - 连续变量
# 列 148: KOOSKPR - 连续变量
# 列 149: HSMSS - 连续变量
# 列 150: WOMKPR - 连续变量
# 列 151: KOOSQOL - 连续变量
# 列 152: KPR30CV - 二分类变量
# 列 153: WOMADLR - 连续变量
# 列 154: HPL12CV - 二分类变量
# 列 155: KPR12CV - 二分类变量
# 列 156: WOMTSR - 连续变量
# 列 157: KPACTCV - 定序变量
# 列 158: WOMKPL - 连续变量
# 列 159: LKP30CV - 二分类变量
# 列 160: PMRKRCV - 连续变量
# 列 161: HSPSS - 连续变量
# 列 162: WOMADLL - 连续变量
# 列 163: P7RKRCV - 连续变量
# 列 164: KPL30CV - 二分类变量
# 列 165: BPACTCV - 二分类变量
# 列 166: KSX - 连续变量
# 列 167: FALL - 二分类变量
# 列 168: CESD1 - 定序变量
# 列 169: CESD2 - 定序变量
# 列 170: CESD3 - 定序变量
# 列 171: CESD4 - 定序变量
# 列 172: CESD5 - 定序变量
# 列 173: CESD6 - 定序变量
# 列 174: CESD7 - 定序变量
# 列 175: CESD8 - 定序变量
# 列 176: CESD9 - 定序变量
# 列 177: CESD10 - 定序变量
# 列 178: CESD11 - 定序变量
# 列 179: CESD12 - 定序变量
# 列 180: CESD13 - 定序变量
# 列 181: CESD14 - 定序变量
# 列 182: CESD15 - 二分类变量
# 列 183: CESD16 - 定序变量
# 列 184: CESD17 - 定序变量
# 列 185: CESD18 - 定序变量
# 列 186: CESD19 - 定序变量
# 列 187: CESD20 - 定序变量
# 列 188: ARTDOC - 二分类变量
# 列 189: KPMED - 二分类变量
# 列 190: TYLEN - 二分类变量
# 列 191: NSAIDS - ID列 (跳过处理)
# 列 192: NSAIDRX - ID列 (跳过处理)
# 列 193: COXIBS - 二分类变量
# 列 194: NARCOT - 二分类变量
# 列 195: SAME - 二分类变量
# 列 196: MSM - 二分类变量
# 列 197: DOXYCYC - 二分类变量
# 列 198: PNMEDT - 二分类变量
# 列 199: CHON - 二分类变量
# 列 200: GLUC - 二分类变量
# 列 201: KNINJ - 二分类变量
# 列 202: PTH - 二分类变量
# 列 203: BISPHOS - 二分类变量
# 列 204: RX30 - 二分类变量
# 列 205: RX30NUM - 连续变量
# 列 206: RXFLUOR - 二分类变量
# 列 207: RXCLCTN - 二分类变量
# 列 208: RXBISPH - 二分类变量
# 列 209: STRINJR - 二分类变量
# 列 210: HYAINJL - 二分类变量
# 列 211: STINJCV - 二分类变量
# 列 212: RXCLCXB - 二分类变量
# 列 213: CESD - 连续变量
# 列 214: RXIHYAL - 二分类变量
# 列 215: HYAINJR - 二分类变量
# 列 216: RXNTRAT - 二分类变量
# 列 217: STRINJL - 二分类变量
# 列 218: RXASPRN - 二分类变量
# 列 219: RXCOX2 - 二分类变量
# 列 220: HYINJCV - 二分类变量
# 列 221: GLCFQCV - 定序变量
# 列 222: RXVLCXB - 二分类变量
# 列 223: CHNFQCV - 定序变量
# 列 224: FALLCV - 定序变量
# 列 225: RXISTRD - 二分类变量
# 列 226: RXMSM - 二分类变量
# 列 227: RXNARC - 二分类变量
# 列 228: RXRFCXB - 二分类变量
# 列 229: RXCHOND - 二分类变量
# 列 230: RXACTM - 二分类变量
# 列 231: RXGLCSM - 二分类变量
# 列 232: KPMEDCV - 二分类变量
# 列 233: BISPTYP - 定序变量
# 列 234: ARTDRCV - 二分类变量
# 列 235: RXANALG - 二分类变量
# 列 236: RXSALIC - 二分类变量
# 列 237: RXNSAID - ID列 (跳过处理)
# 列 238: RXTPRTD - 二分类变量
# 列 239: RXSAME - 二分类变量
# 列 240: RXRALOX - 二分类变量
# 列 241: RXOSTRD - 二分类变量
# 列 242: RXVIT_D - 二分类变量
# 列 243: RXOTHAN - 二分类变量
# 列 244: BPSYS - 连续变量
# 列 245: BPDIAS - 连续变量
# 列 246: CSTSGL - 定序变量
# 列 247: CSTREP1 - 定序变量
# 列 248: CSTIME1 - 连续变量
# 列 249: CSTREP2 - 定序变量
# 列 250: CSTIME2 - 连续变量
# 列 251: WLK20T1 - 二分类变量
# 列 252: STEPST1 - 连续变量
# 列 253: TIMET1 - 连续变量
# 列 254: WLK20T2 - 二分类变量
# 列 255: STEPST2 - 连续变量
# 列 256: TIMET2 - 连续变量
# 列 257: WLKAID - ID列 (跳过处理)
# 列 258: 20MPACE - 连续变量
# 列 259: WEIGHT - 连续变量
# 列 260: BMI - 连续变量
# 列 261: HLTHCAR - 定序变量
# 列 262: HLTHCOV - 二分类变量
# 列 263: MEDINS - 二分类变量
# 列 264: PA230 - 二分类变量
# 列 265: PA330 - 二分类变量
# 列 266: PA530 - 二分类变量
# 列 267: PA430 - 二分类变量
# 列 268: PA130 - 二分类变量
# 列 269: PASE1 - 定序变量
# 列 270: PASE1HR - 定序变量
# 列 271: PASE2 - 定序变量
# 列 272: PASE2HR - 定序变量
# 列 273: PASE3 - 定序变量
# 列 274: PASE4 - 定序变量
# 列 275: PASE5 - 定序变量
# 列 276: PASE6 - 定序变量
# 列 277: HOUACT1 - 二分类变量
# 列 278: HOUACT2 - 二分类变量
# 列 279: HOUACT3 - 二分类变量
# 列 280: HOUACT4 - 二分类变量
# 列 281: HOUACT5 - 二分类变量
# 列 282: HOUACT6 - 二分类变量
# 列 283: WORK7 - 二分类变量
# 列 284: WORKAMT - 定序变量
# 列 285: CUREMP - 二分类变量
# 列 286: WEEKWK - 连续变量
# 列 287: HOURWK - 连续变量
# 列 288: MISSWK - 连续变量
# 列 289: PA530CV - 定序变量
# 列 290: PA330CV - 定序变量
# 列 291: PA130CV - 定序变量
# 列 292: CEMPLOY - 定序变量
# 列 293: PASE - 连续变量
# 列 294: AGE - 连续变量
# 列 295: PA430CV - 定序变量
# 列 296: PA230CV - 定序变量
# 列 297: WKHR7CV - 连续变量
# --------------------------------------------------
# 处理完成！最终数据形状: (300, 297)
# 处理后的文件已保存至: C:\Users\DXW\Desktop\半月板手术_predictor_processed.xlsx
#
# ==================================================
# 处理摘要
# ==================================================
# 原始文件: C:\Users\DXW\Desktop\半月板手术_predictor.xlsx
# 原始数据形状: 300 行 × 297 列
# 处理后形状: 300 行 × 297 列
#
# 列类型统计:
#   ID列: 6
#   二分类变量: 110
#   定序变量: 99
#   连续变量: 82
#
# 列详细信息:
#   ID: id
#   side: id
#   SF1: ordinal
#   SF2: ordinal
#   SF3: ordinal
#   SF4: ordinal
#   SF5: ordinal
#   SF6: ordinal
#   SF7: ordinal
#   SF8: ordinal
#   SF9: ordinal
#   SF10: ordinal
#   SF11: ordinal
#   SF12: ordinal
#   KPNR12: binary
#   KPNR12M: continuous
#   KPNL12: binary
#   KPNL12M: continuous
#   KPACT30: binary
#   WPRKN1: continuous
#   WPRKN2: ordinal
#   WPRKN3: ordinal
#   WPRKN4: ordinal
#   WPRKN5: ordinal
#   KPRKN1: ordinal
#   KPRKN2: continuous
#   KPRKN3: ordinal
#   P7RKFR: ordinal
#   WSRKN1: continuous
#   WSRKN2: continuous
#   KSXRKN1: ordinal
#   KSXRKN2: continuous
#   KSXRKN3: continuous
#   KSXRKN4: continuous
#   KSXRKN5: continuous
#   DIRKN1: ordinal
#   DIRKN2: ordinal
#   DIRKN3: continuous
#   DIRKN4: continuous
#   DIRKN5: ordinal
#   DIRKN6: continuous
#   DIRKN7: ordinal
#   DIRKN8: ordinal
#   DIRKN9: continuous
#   DIRKN10: continuous
#   DIRKN11: continuous
#   DIRKN12: continuous
#   DIRKN13: ordinal
#   DIRKN14: continuous
#   DIRKN15: ordinal
#   DIRKN16: ordinal
#   DIRKN17: continuous
#   WPLKN1: continuous
#   WPLKN2: ordinal
#   WPLKN3: continuous
#   WPLKN4: continuous
#   WPLKN5: continuous
#   KPLKN1: ordinal
#   KPLKN2: ordinal
#   KPLKN3: ordinal
#   P7LKFR: ordinal
#   WSLKN1: ordinal
#   WSLKN2: continuous
#   KSXLKN1: ordinal
#   KSXLKN2: ordinal
#   KSXLKN3: ordinal
#   KSXLKN4: ordinal
#   KSXLKN5: ordinal
#   DILKN1: ordinal
#   DILKN2: ordinal
#   DILKN3: ordinal
#   DILKN4: continuous
#   DILKN5: ordinal
#   DILKN6: continuous
#   DILKN7: ordinal
#   DILKN8: ordinal
#   DILKN9: continuous
#   DILKN10: continuous
#   DILKN11: continuous
#   DILKN12: continuous
#   DILKN13: ordinal
#   DILKN14: continuous
#   DILKN15: ordinal
#   DILKN16: ordinal
#   DILKN17: continuous
#   KOOSFX1: ordinal
#   KOOSFX2: ordinal
#   KOOSFX3: ordinal
#   KOOSFX4: ordinal
#   KOOSFX5: ordinal
#   KQOL1: continuous
#   KQOL2: continuous
#   KQOL3: continuous
#   KQOL4: continuous
#   KGLRS: continuous
#   HPNR12: binary
#   HPNRIL: binary
#   HPNROL: binary
#   HPNRFL: binary
#   HPNRB: binary
#   HPNRLB: binary
#   HPNL12: binary
#   HPNLIL: binary
#   HPNLOL: binary
#   HPNLFL: binary
#   HPNLB: binary
#   HPNLLB: binary
#   BP30: binary
#   BP30OFT: ordinal
#   BPBAD: ordinal
#   BPUB: binary
#   BPMB: binary
#   BPLB: binary
#   BPB: binary
#   OJPNRS: binary
#   OJPNLS: binary
#   OJPNRE: binary
#   OJPNLE: binary
#   OJPNRW: binary
#   OJPNLW: binary
#   OJPNRH: binary
#   OJPNLH: binary
#   OJPNRA: binary
#   OJPNLA: binary
#   OJPNRF: binary
#   OJPNLF: binary
#   OJPNNK: binary
#   OJPNNO: binary
#   WOMTSL: continuous
#   LKSX: continuous
#   KPA30CV: binary
#   KPL12CV: binary
#   BPBEDCV: ordinal
#   BPTOT: continuous
#   RKP30CV: binary
#   KPACDCV: continuous
#   WOMSTFL: continuous
#   PMLKRCV: continuous
#   KOOSYML: continuous
#   HPR12CV: binary
#   KOOSKPL: continuous
#   KOOSFSR: continuous
#   P7LKRCV: continuous
#   BPDAYCV: continuous
#   RKSX: continuous
#   WOMSTFR: continuous
#   KOOSYMR: continuous
#   KOOSKPR: continuous
#   HSMSS: continuous
#   WOMKPR: continuous
#   KOOSQOL: continuous
#   KPR30CV: binary
#   WOMADLR: continuous
#   HPL12CV: binary
#   KPR12CV: binary
#   WOMTSR: continuous
#   KPACTCV: ordinal
#   WOMKPL: continuous
#   LKP30CV: binary
#   PMRKRCV: continuous
#   HSPSS: continuous
#   WOMADLL: continuous
#   P7RKRCV: continuous
#   KPL30CV: binary
#   BPACTCV: binary
#   KSX: continuous
#   FALL: binary
#   CESD1: ordinal
#   CESD2: ordinal
#   CESD3: ordinal
#   CESD4: ordinal
#   CESD5: ordinal
#   CESD6: ordinal
#   CESD7: ordinal
#   CESD8: ordinal
#   CESD9: ordinal
#   CESD10: ordinal
#   CESD11: ordinal
#   CESD12: ordinal
#   CESD13: ordinal
#   CESD14: ordinal
#   CESD15: binary
#   CESD16: ordinal
#   CESD17: ordinal
#   CESD18: ordinal
#   CESD19: ordinal
#   CESD20: ordinal
#   ARTDOC: binary
#   KPMED: binary
#   TYLEN: binary
#   NSAIDS: id
#   NSAIDRX: id
#   COXIBS: binary
#   NARCOT: binary
#   SAME: binary
#   MSM: binary
#   DOXYCYC: binary
#   PNMEDT: binary
#   CHON: binary
#   GLUC: binary
#   KNINJ: binary
#   PTH: binary
#   BISPHOS: binary
#   RX30: binary
#   RX30NUM: continuous
#   RXFLUOR: binary
#   RXCLCTN: binary
#   RXBISPH: binary
#   STRINJR: binary
#   HYAINJL: binary
#   STINJCV: binary
#   RXCLCXB: binary
#   CESD: continuous
#   RXIHYAL: binary
#   HYAINJR: binary
#   RXNTRAT: binary
#   STRINJL: binary
#   RXASPRN: binary
#   RXCOX2: binary
#   HYINJCV: binary
#   GLCFQCV: ordinal
#   RXVLCXB: binary
#   CHNFQCV: ordinal
#   FALLCV: ordinal
#   RXISTRD: binary
#   RXMSM: binary
#   RXNARC: binary
#   RXRFCXB: binary
#   RXCHOND: binary
#   RXACTM: binary
#   RXGLCSM: binary
#   KPMEDCV: binary
#   BISPTYP: ordinal
#   ARTDRCV: binary
#   RXANALG: binary
#   RXSALIC: binary
#   RXNSAID: id
#   RXTPRTD: binary
#   RXSAME: binary
#   RXRALOX: binary
#   RXOSTRD: binary
#   RXVIT_D: binary
#   RXOTHAN: binary
#   BPSYS: continuous
#   BPDIAS: continuous
#   CSTSGL: ordinal
#   CSTREP1: ordinal
#   CSTIME1: continuous
#   CSTREP2: ordinal
#   CSTIME2: continuous
#   WLK20T1: binary
#   STEPST1: continuous
#   TIMET1: continuous
#   WLK20T2: binary
#   STEPST2: continuous
#   TIMET2: continuous
#   WLKAID: id
#   20MPACE: continuous
#   WEIGHT: continuous
#   BMI: continuous
#   HLTHCAR: ordinal
#   HLTHCOV: binary
#   MEDINS: binary
#   PA230: binary
#   PA330: binary
#   PA530: binary
#   PA430: binary
#   PA130: binary
#   PASE1: ordinal
#   PASE1HR: ordinal
#   PASE2: ordinal
#   PASE2HR: ordinal
#   PASE3: ordinal
#   PASE4: ordinal
#   PASE5: ordinal
#   PASE6: ordinal
#   HOUACT1: binary
#   HOUACT2: binary
#   HOUACT3: binary
#   HOUACT4: binary
#   HOUACT5: binary
#   HOUACT6: binary
#   WORK7: binary
#   WORKAMT: ordinal
#   CUREMP: binary
#   WEEKWK: continuous
#   HOURWK: continuous
#   MISSWK: continuous
#   PA530CV: ordinal
#   PA330CV: ordinal
#   PA130CV: ordinal
#   CEMPLOY: ordinal
#   PASE: continuous
#   AGE: continuous
#   PA430CV: ordinal
#   PA230CV: ordinal
#   WKHR7CV: continuous
#
# 前5行数据预览:
#         ID  side  SF1  SF2  SF3  SF4  SF5  SF6  SF7  SF8  ...    MISSWK  \
# 0  9043637     1  2.0  2.0  2.0  5.0  5.0  5.0  5.0  2.0  ...  0.805128
# 1  9063955     2  2.0  3.0  2.0  5.0  5.0  5.0  5.0  1.0  ...  0.805128
# 2  9070207     2  2.0  2.0  2.0  3.0  2.0  5.0  5.0  3.0  ...  0.000000
# 3  9091787     1  1.0  2.0  3.0  2.0  2.0  5.0  5.0  4.0  ...  0.805128
# 4  9177408     2  3.0  1.0  1.0  2.0  1.0  5.0  5.0  4.0  ...  0.000000
#
#    PA530CV  PA330CV  PA130CV  CEMPLOY   PASE  AGE  PA430CV  PA230CV  WKHR7CV
# 0      0.0      0.0      0.0      4.0   82.0   75      2.0      0.0     12.0
# 1      0.0      0.0      0.0      4.0  202.0   69      2.0      0.0     24.0
# 2      0.0      0.0      0.0      1.0  337.0   55      2.0      0.0     60.0
# 3      0.0      0.0      4.0      4.0  148.0   64      3.0      4.0      0.0
# 4      0.0      0.0      0.0      1.0  101.0   73      2.0      2.0     16.0
#
# [5 rows x 297 columns]
