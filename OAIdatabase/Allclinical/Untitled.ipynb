# %%
import pandas as pd
src = pd.read_excel(r"C:\Users\DXW\OAI data\OAIdatabase\Allclinical\Allclinical09.xlsx", dtype=str)
print('总列数:', src.shape[1])
# 前 20 列看看
print(src.columns[:20].tolist())
# Out:
# 总列数: 259
# ['ID', 'VERSION', 'V09KPNR12', 'V09KPNR12M', 'V09KPNL12', 'V09KPNL12M', 'V09KPACT30', 'V09WPRKN1', 'V09WPRKN2', 'V09WPRKN3', 'V09WPRKN4', 'V09WPRKN5', 'V09KPRKN1', 'V09KPRKN2', 'V09KPRKN3', 'V09P7RKFR', 'V09WSRKN1', 'V09WSRKN2', 'V09KSXRKN1', 'V09KSXRKN2']

# %%
want = ['V09BLDCOLL', 'V09BLUPMM1', 'V09SF1']   # 任意挑几个
have = set(src.columns.str.upper())
for w in want:
    print(w, '✔' if w in have else '✖')
# Out:
# V09BLDCOLL ✖
# V09BLUPMM1 ✖
# V09SF1 ✖
